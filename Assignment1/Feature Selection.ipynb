# %%
import pandas as pd

# %%
data = pd.read_pickle('data_clean_daily.pkl')

# %%
data.columns = [' '.join(col).strip() for col in data.columns.values]

# %%
data
# Out:
#            id       time  mood min  mood max  mood median  mood mean  \
# 0     AS14.01 2014-03-21       6.0       7.0          6.0       6.20
# 1     AS14.01 2014-03-22       5.0       7.0          7.0       6.40
# 2     AS14.01 2014-03-23       6.0       8.0          7.0       6.80
# 3     AS14.01 2014-03-24       5.0       7.0          6.0       6.00
# 4     AS14.01 2014-03-25       6.0       8.0          6.5       6.75
# ...       ...        ...       ...       ...          ...        ...
# 1297  AS14.33 2014-05-27       5.0       7.0          6.0       6.20
# 1298  AS14.33 2014-05-28       6.0      10.0          9.0       8.20
# 1299  AS14.33 2014-05-29       7.0       7.0          7.0       7.00
# 1300  AS14.33 2014-05-30       6.0       8.0          6.0       6.80
# 1301  AS14.33 2014-05-31       7.0       7.0          7.0       7.00
#
#       mood std  mood count  circumplex.arousal min  circumplex.arousal max  \
# ...
